# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder




from sklearn.metrics import r2_score
# from sklearn.cluster import KMeans

# %%
df=pd.read_csv('pollution.csv')
print(len(df))
df.head()
df['Air Quality'].unique()
# Out:
# 5000
# array(['Moderate', 'Good', 'Hazardous', 'Poor'], dtype=object)

# %%
df.head()
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate
# 3                           11.1                 551        Good
# 4                           12.7                 303        Good

# %%
df['Air Quality'].unique()
# Out:
# array(['Moderate', 'Good', 'Hazardous', 'Poor'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2.5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   Air Quality                    5000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#        Temperature     Humidity        PM2.5         PM10          NO2  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     30.029020    70.056120    20.142140    30.218360    26.412100
# std       6.720661    15.863577    24.554546    27.349199     8.895356
# min      13.400000    36.000000     0.000000    -0.200000     7.400000
# 25%      25.100000    58.300000     4.600000    12.300000    20.100000
# 50%      29.000000    69.800000    12.000000    21.700000    25.300000
# 75%      34.000000    80.300000    26.100000    38.100000    31.900000
# max      58.600000   128.100000   295.000000   315.800000    64.900000
#
#                SO2           CO  Proximity_to_Industrial_Areas  \
# count  5000.000000  5000.000000                    5000.000000
# mean     10.014820     1.500354                       8.425400
# std       6.750303     0.546027                       3.610944
# min      -6.200000     0.650000                       2.500000
# ...

# %%
df.isnull().sum()
# Out:
# Temperature                      0
# Humidity                         0
# PM2.5                            0
# PM10                             0
# NO2                              0
# SO2                              0
# CO                               0
# Proximity_to_Industrial_Areas    0
# Population_Density               0
# Air Quality                      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Temperature                      0
# Humidity                         0
# PM2.5                            0
# PM10                             0
# NO2                              0
# SO2                              0
# CO                               0
# Proximity_to_Industrial_Areas    0
# Population_Density               0
# Air Quality                      0
# dtype: int64

# %%
encoder=LabelEncoder()
df['Air Quality']=encoder.fit_transform(df['Air Quality'])
df.tail()
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density  Air Quality
# 4995                            2.8                 765            1
# 4996                            5.7                 709            2
# 4997                            9.6                 379            2
# 4998                           11.6                 241            0
# 4999                            8.3                 461            2

# %%
a=[]
for i in df:
    a.append(i)
    plt.boxplot(df[i])
    plt.title(i)
    plt.figsize=(2,5)
    # plt.figure(figsize=(20, 20)) 
    plt.tight_layout()
    plt.show()

# %%
df.corr()
# Out:
#                                Temperature  Humidity     PM2.5      PM10  \
# Temperature                       1.000000  0.466456  0.323840  0.425690
# Humidity                          0.466456  1.000000  0.273366  0.359156
# PM2.5                             0.323840  0.273366  1.000000  0.973005
# PM10                              0.425690  0.359156  0.973005  1.000000
# NO2                               0.591969  0.491977  0.333004  0.439916
# SO2                               0.568082  0.459804  0.299582  0.401849
# CO                                0.685258  0.567540  0.395179  0.518895
# Proximity_to_Industrial_Areas    -0.589564 -0.479646 -0.315766 -0.425018
# Population_Density                0.481692  0.411630  0.278957  0.365734
# Air Quality                       0.501446  0.430633  0.268432  0.366493
#
#                                     NO2       SO2        CO  \
# Temperature                    0.591969  0.568082  0.685258
# ...

# %%
y=df['Air Quality']

# %%
x=df.drop(columns='Air Quality')

# %% [markdown]
# # Split data for test and train

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)
x_test
# Out:
#       Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 3566         31.6      85.1    4.5  19.4  29.0  11.9  1.23
# 4252         34.6      73.0   21.1  47.9  38.7  21.2  2.64
# 1918         30.4      93.5    8.5  29.2  36.6  16.3  1.64
# 4111         24.6      66.9   14.4  19.2  25.2   5.9  1.01
# 1471         30.8      84.4   34.2  50.3  27.8  16.1  1.30
# ...           ...       ...    ...   ...   ...   ...   ...
# 2987         19.2      51.9    6.3  10.6  20.9   7.7  1.10
# 3564         47.3      98.9    5.5  30.3  39.6  11.2  2.56
# 1447         31.3      75.0   37.8  47.1  32.6  11.0  1.87
# 742          31.1      67.6    2.2   5.5  11.3   0.8  1.12
# 4121         26.3      73.3   17.7  23.6  35.2  14.1  1.77
#
#       Proximity_to_Industrial_Areas  Population_Density
# 3566                            6.3                 429
# 4252                            5.6                 704
# 1918                            6.0                 766
# ...

# %%
from sklearn.tree import DecisionTreeClassifier as dtc

# %%
cls=dtc(criterion='entropy',random_state=3)
cls.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=3)

# %%
pred=cls.predict(x_test)

# %% [markdown]
# # Check score

# %%
r2_score(pred,y_test)
# Out:
# 0.83359595492202

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix
result=cm(pred,y_test)
result
# Out:
# array([[423,   0,   2,   0],
#        [  0,  80,   0,  23],
#        [  0,   0, 287,  11],
#        [  0,  25,  17, 132]], dtype=int64)

# %% [markdown]
# # Custome checking

# %%
a=pd.DataFrame([[26.5,70.7,6.9,16.0,21.9,5.6,1.01,12.7,303]])

# %%
pred_c=cls.predict(a)
# Out:
# C:\Users\91708\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
dd=['Moderate', 'Good', 'Hazardous', 'Poor']

# %%
encoder.fit(dd)
# Out:
# LabelEncoder()

# %%
pred_strings = encoder.inverse_transform(pred_c)

# %%
pred_strings
# Out:
# array(['Good'], dtype='<U9')
